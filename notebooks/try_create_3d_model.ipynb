# %%
import sys
sys.path.append("../pytorch3dunet/unet3d")

# %%
from model import ResidualUNet3D
import torch

# %%
model = ResidualUNet3D(in_channels=1, out_channels=5, f_maps = [32, 64, 128, 256, 512], final_sigmoid=False)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
device
# Out:
# device(type='cuda')

# %%
fun_tensor = torch.rand(1, 1, 256, 256, 128).to(device)

# %%
from torchsummary import summary
summary(model, (1, 256, 256, 96))
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ├─ModuleList: 1                               []                        --
# |    └─Encoder: 2-1                           [-1, 32, 256, 256, 96]    --
# |    |    └─ResNetBlock: 3-1                  [-1, 32, 256, 256, 96]    55,488
# |    └─Encoder: 2-2                           [-1, 64, 128, 128, 48]    --
# |    |    └─MaxPool3d: 3-2                    [-1, 32, 128, 128, 48]    --
# |    |    └─ResNetBlock: 3-3                  [-1, 64, 128, 128, 48]    223,552
# |    └─Encoder: 2-3                           [-1, 128, 64, 64, 24]     --
# |    |    └─MaxPool3d: 3-4                    [-1, 64, 64, 64, 24]      --
# |    |    └─ResNetBlock: 3-5                  [-1, 128, 64, 64, 24]     893,568
# |    └─Encoder: 2-4                           [-1, 256, 32, 32, 12]     --
# |    |    └─MaxPool3d: 3-6                    [-1, 128, 32, 32, 12]     --
# |    |    └─ResNetBlock: 3-7                  [-1, 256, 32, 32, 12]     3,572,992
# |    └─Encoder: 2-5                           [-1, 512, 16, 16, 6]      --
# |    |    └─MaxPool3d: 3-8                    [-1, 256, 16, 16, 6]      --
# |    |    └─ResNetBlock: 3-9                  [-1, 512, 16, 16, 6]      14,289,408
# ├─ModuleList: 1                               []                        --
# |    └─Decoder: 2-6                           [-1, 256, 32, 32, 12]     --
# |    |    └─TransposeConvUpsampling: 3-10     [-1, 256, 32, 32, 12]     3,539,200
# |    |    └─ResNetBlock: 3-11                 [-1, 256, 32, 32, 12]     3,539,968
# |    └─Decoder: 2-7                           [-1, 128, 64, 64, 24]     --
# |    |    └─TransposeConvUpsampling: 3-12     [-1, 128, 64, 64, 24]     884,864
# |    |    └─ResNetBlock: 3-13                 [-1, 128, 64, 64, 24]     885,248
# |    └─Decoder: 2-8                           [-1, 64, 128, 128, 48]    --
# |    |    └─TransposeConvUpsampling: 3-14     [-1, 64, 128, 128, 48]    221,248
# |    |    └─ResNetBlock: 3-15                 [-1, 64, 128, 128, 48]    221,440
# |    └─Decoder: 2-9                           [-1, 32, 256, 256, 96]    --
# |    |    └─TransposeConvUpsampling: 3-16     [-1, 32, 256, 256, 96]    55,328
# |    |    └─ResNetBlock: 3-17                 [-1, 32, 256, 256, 96]    55,424
# ├─Conv3d: 1-1                                 [-1, 5, 256, 256, 96]     165
# ├─Softmax: 1-2                                [-1, 5, 256, 256, 96]     --
# ===============================================================================================
# Total params: 28,437,893
# Trainable params: 28,437,893
# Non-trainable params: 0
# Total mult-adds (G): 656.61
# ===============================================================================================
# Input size (MB): 24.00
# Forward/backward pass size (MB): 4326.00
# Params size (MB): 108.48
# Estimated Total Size (MB): 4458.48
# ===============================================================================================
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# ├─ModuleList: 1                               []                        --
# |    └─Encoder: 2-1                           [-1, 32, 256, 256, 96]    --
# |    |    └─ResNetBlock: 3-1                  [-1, 32, 256, 256, 96]    55,488
# |    └─Encoder: 2-2                           [-1, 64, 128, 128, 48]    --
# |    |    └─MaxPool3d: 3-2                    [-1, 32, 128, 128, 48]    --
# |    |    └─ResNetBlock: 3-3                  [-1, 64, 128, 128, 48]    223,552
# |    └─Encoder: 2-3                           [-1, 128, 64, 64, 24]     --
# |    |    └─MaxPool3d: 3-4                    [-1, 64, 64, 64, 24]      --
# |    |    └─ResNetBlock: 3-5                  [-1, 128, 64, 64, 24]     893,568
# |    └─Encoder: 2-4                           [-1, 256, 32, 32, 12]     --
# |    |    └─MaxPool3d: 3-6                    [-1, 128, 32, 32, 12]     --
# |    |    └─ResNetBlock: 3-7                  [-1, 256, 32, 32, 12]     3,572,992
# |    └─Encoder: 2-5                           [-1, 512, 16, 16, 6]      --
# |    |    └─MaxPool3d: 3-8                    [-1, 256, 16, 16, 6]      --
# |    |    └─ResNetBlock: 3-9                  [-1, 512, 16, 16, 6]      14,289,408
# ├─ModuleList: 1                               []                        --
# |    └─Decoder: 2-6                           [-1, 256, 32, 32, 12]     --
# |    |    └─TransposeConvUpsampling: 3-10     [-1, 256, 32, 32, 12]     3,539,200
# |    |    └─ResNetBlock: 3-11                 [-1, 256, 32, 32, 12]     3,539,968
# |    └─Decoder: 2-7                           [-1, 128, 64, 64, 24]     --
# |    |    └─TransposeConvUpsampling: 3-12     [-1, 128, 64, 64, 24]     884,864
# |    |    └─ResNetBlock: 3-13                 [-1, 128, 64, 64, 24]     885,248
# |    └─Decoder: 2-8                           [-1, 64, 128, 128, 48]    --
# |    |    └─TransposeConvUpsampling: 3-14     [-1, 64, 128, 128, 48]    221,248
# |    |    └─ResNetBlock: 3-15                 [-1, 64, 128, 128, 48]    221,440
# |    └─Decoder: 2-9                           [-1, 32, 256, 256, 96]    --
# |    |    └─TransposeConvUpsampling: 3-16     [-1, 32, 256, 256, 96]    55,328
# |    |    └─ResNetBlock: 3-17                 [-1, 32, 256, 256, 96]    55,424
# ├─Conv3d: 1-1                                 [-1, 5, 256, 256, 96]     165
# ├─Softmax: 1-2                                [-1, 5, 256, 256, 96]     --
# ===============================================================================================
# Total params: 28,437,893
# Trainable params: 28,437,893
# Non-trainable params: 0
# Total mult-adds (G): 656.61
# ===============================================================================================
# Input size (MB): 24.00
# Forward/backward pass size (MB): 4326.00
# Params size (MB): 108.48
# Estimated Total Size (MB): 4458.48
# ===============================================================================================

# %%
pip list
# Out:
# Package                      Version
# ---------------------------- ------------
# absl-py                      2.0.0
# albumentations               1.3.1
# anyio                        4.0.0
# apptools                     5.2.1
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.2.3
# asttokens                    2.4.0
# astunparse                   1.6.3
# async-lru                    2.0.4
# attrs                        23.1.0
# Babel                        2.12.1
# backcall                     0.2.0
# beautifulsoup4               4.12.2
# bleach                       6.0.0
# bqplot                       0.12.40
# cachetools                   5.3.1
# certifi                      2022.12.7
# cffi                         1.15.1
# charset-normalizer           2.1.1
# classification-models-3D     1.0.7
# colorama                     0.4.6
# comm                         0.1.4
# configobj                    5.0.8
# contourpy                    1.1.1
# cycler                       0.11.0
# debugpy                      1.8.0
# decorator                    5.1.1
# defusedxml                   0.7.1
# envisage                     7.0.3
# exceptiongroup               1.1.3
# executing                    1.2.0
# fastjsonschema               2.18.0
# filelock                     3.9.0
# flatbuffers                  23.5.26
# fonttools                    4.42.1
# fqdn                         1.5.1
# fsspec                       2023.9.2
# gast                         0.4.0
# google-auth                  2.23.0
# google-auth-oauthlib         1.0.0
# google-pasta                 0.2.0
# grpcio                       1.58.0
# h5py                         3.9.0
# huggingface-hub              0.17.2
# idna                         3.4
# imageio                      2.31.3
# imgaug                       0.4.0
# ipydatawidgets               4.3.5
# ipykernel                    6.25.2
# ipympl                       0.9.3
# ipython                      8.15.0
# ipython-genutils             0.2.0
# ipyvolume                    0.6.0
# ipyvue                       1.10.1
# ipyvuetify                   1.8.10
# ipywebrtc                    0.6.0
# ipywidgets                   8.1.1
# isoduration                  20.11.0
# jedi                         0.19.0
# Jinja2                       3.1.2
# joblib                       1.3.2
# json5                        0.9.14
# jsonpointer                  2.4
# jsonschema                   4.19.1
# jsonschema-specifications    2023.7.1
# jupyter                      1.0.0
# jupyter_client               8.3.1
# jupyter-console              6.6.3
# jupyter_core                 5.3.1
# jupyter-events               0.7.0
# jupyter-lsp                  2.2.0
# jupyter_server               2.7.3
# jupyter_server_terminals     0.4.4
# jupyterlab                   4.0.6
# jupyterlab-pygments          0.2.2
# jupyterlab_server            2.25.0
# jupyterlab-widgets           3.0.9
# keras                        2.13.1
# Keras-Applications           1.0.8
# kiwisolver                   1.4.5
# lazy_loader                  0.3
# libclang                     16.0.6
# loguru                       0.7.2
# Markdown                     3.4.4
# MarkupSafe                   2.1.2
# matplotlib                   3.8.0
# matplotlib-inline            0.1.6
# mayavi                       4.8.1
# mistune                      3.0.1
# mpmath                       1.2.1
# nbclient                     0.8.0
# nbconvert                    7.8.0
# nbformat                     5.9.2
# nest-asyncio                 1.5.8
# networkx                     3.0
# nibabel                      5.1.0
# notebook                     7.0.4
# notebook_shim                0.2.3
# numpy                        1.24.1
# oauthlib                     3.2.2
# opencv-python                4.8.0.76
# opencv-python-headless       4.8.0.76
# opt-einsum                   3.3.0
# overrides                    7.4.0
# packaging                    23.1
# pandas                       2.1.1
# pandocfilters                1.5.0
# parso                        0.8.3
# pickleshare                  0.7.5
# Pillow                       9.3.0
# pip                          23.2.1
# platformdirs                 3.10.0
# prometheus-client            0.17.1
# prompt-toolkit               3.0.39
# protobuf                     4.24.3
# psutil                       5.9.5
# pure-eval                    0.2.2
# pyasn1                       0.5.0
# pyasn1-modules               0.3.0
# pycparser                    2.21
# pydicom                      2.4.3
# pyface                       8.0.0
# Pygments                     2.16.1
# pyparsing                    3.1.1
# python-box                   7.1.1
# python-dateutil              2.8.2
# python-json-logger           2.0.7
# pythreejs                    2.4.2
# pytz                         2023.3.post1
# PyWavelets                   1.4.1
# pywin32                      306
# pywinpty                     2.0.11
# PyYAML                       6.0.1
# pyzmq                        25.1.1
# qtconsole                    5.4.4
# QtPy                         2.4.0
# qudida                       0.0.4
# referencing                  0.30.2
# regex                        2023.8.8
# requests                     2.31.0
# requests-oauthlib            1.3.1
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rpds-py                      0.10.3
# rsa                          4.9
# safetensors                  0.3.3
# scikit-image                 0.21.0
# scikit-learn                 1.3.0
# scipy                        1.11.2
# Send2Trash                   1.8.2
# setuptools                   68.1.2
# shapely                      2.0.1
# six                          1.16.0
# sniffio                      1.3.0
# soupsieve                    2.5
# stack-data                   0.6.2
# sympy                        1.11.1
# tabulate                     0.9.0
# tensorboard                  2.13.0
# tensorboard-data-server      0.7.1
# tensorflow                   2.13.0
# tensorflow-estimator         2.13.0
# tensorflow-intel             2.13.0
# tensorflow-io-gcs-filesystem 0.31.0
# termcolor                    2.3.0
# terminado                    0.17.1
# threadpoolctl                3.2.0
# tifffile                     2023.9.18
# tinycss2                     1.2.1
# tokenizers                   0.13.3
# tomli                        2.0.1
# torch                        2.0.1+cu117
# torch-summary                1.4.5
# torchaudio                   2.0.2+cu117
# torchvision                  0.15.2+cu117
# tornado                      6.3.3
# tqdm                         4.66.1
# traitlets                    5.10.0
# traits                       6.4.2
# traitsui                     8.0.0
# traittypes                   0.2.1
# transformers                 4.33.2
# typing_extensions            4.4.0
# tzdata                       2023.3
# uri-template                 1.3.0
# urllib3                      1.26.13
# volumentations-3D            1.0.4
# vtk                          9.2.6
# wcwidth                      0.2.6
# webcolors                    1.13
# webencodings                 0.5.1
# websocket-client             1.6.3
# Werkzeug                     2.3.7
# wheel                        0.41.2
# widgetsnbextension           4.0.9
# win32-setctime               1.1.0
# wrapt                        1.15.0
# Note: you may need to restart the kernel to use updated packages.

# %%
answer = model.forward(fun_tensor)

# %%
answer.shape
# Out:
# torch.Size([1, 5, 256, 256, 64])

# %%
bb = torch.sigmoid(answer)

# %%
bb.min(), bb.max()
# Out:
# (tensor(0.1225, device='cuda:0', grad_fn=<MinBackward1>),
#  tensor(0.9021, device='cuda:0', grad_fn=<MaxBackward1>))

# %%
answer.min()
# Out:
# tensor(-1.9690, device='cuda:0', grad_fn=<MinBackward1>)

# %%
model
# Out:
# ResidualUNet3D(
#   (encoders): ModuleList(
#     (0): Encoder(
#       (basic_module): ResNetBlock(
#         (conv1): Conv3d(1, 32, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (conv2): SingleConv(
#           (groupnorm): GroupNorm(8, 32, eps=1e-05, affine=True)
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#         (conv3): SingleConv(
#           (groupnorm): GroupNorm(8, 32, eps=1e-05, affine=True)
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         )
#         (non_linearity): ReLU(inplace=True)
#       )
#     )
#     (1): Encoder(
#       (pooling): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (basic_module): ResNetBlock(
#         (conv1): Conv3d(32, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (conv2): SingleConv(
#           (groupnorm): GroupNorm(8, 64, eps=1e-05, affine=True)
#           (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#         (conv3): SingleConv(
#           (groupnorm): GroupNorm(8, 64, eps=1e-05, affine=True)
#           (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         )
#         (non_linearity): ReLU(inplace=True)
#       )
#     )
#     (2): Encoder(
#       (pooling): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (basic_module): ResNetBlock(
#         (conv1): Conv3d(64, 128, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (conv2): SingleConv(
#           (groupnorm): GroupNorm(8, 128, eps=1e-05, affine=True)
#           (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#         (conv3): SingleConv(
#           (groupnorm): GroupNorm(8, 128, eps=1e-05, affine=True)
#           (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         )
#         (non_linearity): ReLU(inplace=True)
#       )
#     )
#     (3): Encoder(
#       (pooling): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (basic_module): ResNetBlock(
#         (conv1): Conv3d(128, 256, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (conv2): SingleConv(
#           (groupnorm): GroupNorm(8, 256, eps=1e-05, affine=True)
#           (conv): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#         (conv3): SingleConv(
#           (groupnorm): GroupNorm(8, 256, eps=1e-05, affine=True)
#           (conv): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         )
#         (non_linearity): ReLU(inplace=True)
#       )
#     )
#     (4): Encoder(
#       (pooling): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#       (basic_module): ResNetBlock(
#         (conv1): Conv3d(256, 512, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#         (conv2): SingleConv(
#           (groupnorm): GroupNorm(8, 512, eps=1e-05, affine=True)
#           (conv): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#         (conv3): SingleConv(
#           (groupnorm): GroupNorm(8, 512, eps=1e-05, affine=True)
#           (conv): Conv3d(512, 512, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         )
#         (non_linearity): ReLU(inplace=True)
#       )
#     )
#   )
#   (decoders): ModuleList(
#     (0): Decoder(
#       (upsampling): TransposeConvUpsampling(
#         (upsample): ConvTranspose3d(512, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#       )
#       (basic_module): ResNetBlock(
#         (conv1): Identity()
#         (conv2): SingleConv(
#           (groupnorm): GroupNorm(8, 256, eps=1e-05, affine=True)
#           (conv): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#         (conv3): SingleConv(
#           (groupnorm): GroupNorm(8, 256, eps=1e-05, affine=True)
#           (conv): Conv3d(256, 256, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         )
#         (non_linearity): ReLU(inplace=True)
#       )
#     )
#     (1): Decoder(
#       (upsampling): TransposeConvUpsampling(
#         (upsample): ConvTranspose3d(256, 128, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#       )
#       (basic_module): ResNetBlock(
#         (conv1): Identity()
#         (conv2): SingleConv(
#           (groupnorm): GroupNorm(8, 128, eps=1e-05, affine=True)
#           (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#         (conv3): SingleConv(
#           (groupnorm): GroupNorm(8, 128, eps=1e-05, affine=True)
#           (conv): Conv3d(128, 128, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         )
#         (non_linearity): ReLU(inplace=True)
#       )
#     )
#     (2): Decoder(
#       (upsampling): TransposeConvUpsampling(
#         (upsample): ConvTranspose3d(128, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#       )
#       (basic_module): ResNetBlock(
#         (conv1): Identity()
#         (conv2): SingleConv(
#           (groupnorm): GroupNorm(8, 64, eps=1e-05, affine=True)
#           (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#         (conv3): SingleConv(
#           (groupnorm): GroupNorm(8, 64, eps=1e-05, affine=True)
#           (conv): Conv3d(64, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         )
#         (non_linearity): ReLU(inplace=True)
#       )
#     )
#     (3): Decoder(
#       (upsampling): TransposeConvUpsampling(
#         (upsample): ConvTranspose3d(64, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#       )
#       (basic_module): ResNetBlock(
#         (conv1): Identity()
#         (conv2): SingleConv(
#           (groupnorm): GroupNorm(8, 32, eps=1e-05, affine=True)
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#           (ReLU): ReLU(inplace=True)
#         )
#         (conv3): SingleConv(
#           (groupnorm): GroupNorm(8, 32, eps=1e-05, affine=True)
#           (conv): Conv3d(32, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#         )
#         (non_linearity): ReLU(inplace=True)
#       )
#     )
#   )
#   (final_conv): Conv3d(32, 5, kernel_size=(1, 1, 1), stride=(1, 1, 1))
#   (final_activation): Softmax(dim=1)
# )
